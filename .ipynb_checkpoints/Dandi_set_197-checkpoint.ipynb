# %% [markdown]
# # BIPN 162 Final Project
# ByEmily McClung, Naomi Ortega, and Isabel Rodriguez

# %%
# !pip install pynwb h5py torch scikit-learn configmypy tensorboardX
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pynwb in /home/emcclung/.local/lib/python3.11/site-packages (3.1.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (3.11.0)
# Requirement already satisfied: torch in /home/emcclung/.local/lib/python3.11/site-packages (2.10.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: configmypy in /home/emcclung/.local/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: tensorboardX in /home/emcclung/.local/lib/python3.11/site-packages (2.6.4)
# Requirement already satisfied: hdmf<5,>=4.1.2 in /home/emcclung/.local/lib/python3.11/site-packages (from pynwb) (4.3.1)
# Requirement already satisfied: numpy>=1.24.0 in /home/emcclung/.local/lib/python3.11/site-packages (from pynwb) (2.4.2)
# Requirement already satisfied: pandas>=1.2.0 in /home/emcclung/.local/lib/python3.11/site-packages (from pynwb) (1.5.3)
# Requirement already satisfied: platformdirs>=4.1.0 in /opt/conda/lib/python3.11/site-packages (from pynwb) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pynwb) (2.9.0)
# Requirement already satisfied: filelock in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/conda/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/emcclung/.local/lib/python3.11/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/emcclung/.local/lib/python3.11/site-packages (from cuda-bindings==12.9.4->torch) (1.4.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/emcclung/.local/lib/python3.11/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.11/site-packages (from configmypy) (8.3.4)
# Requirement already satisfied: pytest-mock in /home/emcclung/.local/lib/python3.11/site-packages (from configmypy) (3.15.1)
# Requirement already satisfied: ruamel.yaml in /opt/conda/lib/python3.11/site-packages (from configmypy) (0.18.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorboardX) (24.0)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.11/site-packages (from tensorboardX) (4.25.5)
# Requirement already satisfied: jsonschema>=3.2.0 in /opt/conda/lib/python3.11/site-packages (from hdmf<5,>=4.1.2->pynwb) (4.21.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2.0->pynwb) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pynwb) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.11/site-packages (from ruamel.yaml->configmypy) (0.2.8)
# Collecting numpy>=1.24.0 (from pynwb)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.11/site-packages (from pytest->configmypy) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/conda/lib/python3.11/site-packages (from pytest->configmypy) (1.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb) (0.18.0)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 66.8 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.2
#     Uninstalling numpy-2.4.2:
#       Successfully uninstalled numpy-2.4.2
#   WARNING: The script f2py is installed in '/home/emcclung/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# allensdk 2.16.2 requires numpy<1.24, but you have numpy 1.26.4 which is incompatible.
# tensorflow 2.15.0 requires ml-dtypes~=0.2.0, but you have ml-dtypes 0.5.4 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.10.0 which is incompatible.
# dask-expr 1.0.11 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
#CLone the DUNL algorithm GitHub Repository
# !git clone https://github.com/btolooshams/dunl-compneuro.git
# Out:
# fatal: destination path 'dunl-compneuro' already exists and is not an empty directory.

# %%
import numpy as np
import torch
import sklearn
import h5py
import configmypy

#Import the DUNL code
import sys
sys.path.append("dunl-compneuro")
import dunl

#Imports for data
import os
from pynwb import NWBHDF5IO
os.makedirs("data", exist_ok=True)

# %%
# !ls dunl-compneuro/dunl
# Out:
# boardfunc.py	     train_fiber_loop_acrossneurons.py
# datasetloader.py     train_independentkernels_acrossneurons.py
# lossfunc.py	     train_sharekernels_acrossneurons.py
# model.py	     train_sharekernels_acrossneurons_groupneuralfirings.py
# postprocess_scripts  utils.py
# preprocess_scripts

# %% [markdown]
# ## Applying DUNL to another dataset
#
# We will now apply the DUNL analysis method to a dataset of Fiber Photometry and Optogenetics recordings.

# %%
#download the dataset DANDI 000971
# !pip install dandi
# !/home/emcclung/.local/bin/dandi download \
"https://dandiarchive.org/dandiset/000971/0.260213.1851/files?location=sub-028-392" \
--output-dir data
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dandi in /home/emcclung/.local/lib/python3.11/site-packages (0.74.3)
# Requirement already satisfied: bidsschematools~=1.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (1.2.1)
# Requirement already satisfied: bids-validator-deno>=2.0.5 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (2.4.1)
# Requirement already satisfied: click<8.2.0,>=7.1 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (8.1.8)
# Requirement already satisfied: click-didyoumean in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.3.1)
# Requirement already satisfied: dandischema~=0.12.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.12.1)
# Requirement already satisfied: etelemetry>=0.2.2 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.3.1)
# Requirement already satisfied: fasteners in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.20)
# Requirement already satisfied: fscacher>=0.3.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.4.4)
# Requirement already satisfied: hdmf!=3.14.4,!=3.5.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (4.3.1)
# Requirement already satisfied: humanize in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (4.15.0)
# Requirement already satisfied: interleave~=0.3 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.3.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from dandi) (1.4.0)
# Requirement already satisfied: keyring!=23.9.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (25.7.0)
# Requirement already satisfied: keyrings.alt in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (5.0.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from dandi) (24.0)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.11/site-packages (from dandi) (4.2.0)
# Requirement already satisfied: pycryptodomex in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (3.23.0)
# Requirement already satisfied: pydantic~=2.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (2.12.5)
# Requirement already satisfied: pynwb!=1.1.0,!=2.3.0,>=1.0.3 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (3.1.3)
# Requirement already satisfied: numcodecs<0.16 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.15.1)
# Requirement already satisfied: nwbinspector!=0.4.32,>=0.4.28 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.7.0)
# Requirement already satisfied: pyout!=0.6.0,>=0.5 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.8.1)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.11/site-packages (from dandi) (2.9.0)
# Requirement already satisfied: requests~=2.20 in /opt/conda/lib/python3.11/site-packages (from dandi) (2.32.3)
# Requirement already satisfied: ruamel.yaml<1,>=0.15 in /opt/conda/lib/python3.11/site-packages (from dandi) (0.18.6)
# Requirement already satisfied: semantic-version in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (2.10.0)
# Requirement already satisfied: tenacity in /opt/conda/lib/python3.11/site-packages (from dandi) (9.0.0)
# Requirement already satisfied: tensorstore in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.1.81)
# Requirement already satisfied: urllib3>=2.0.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (2.6.3)
# Requirement already satisfied: yarl~=1.9 in /opt/conda/lib/python3.11/site-packages (from dandi) (1.9.4)
# Requirement already satisfied: zarr<=3.1.5,>=2.10 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (2.18.7)
# Requirement already satisfied: zarr_checksum~=0.4.0 in /home/emcclung/.local/lib/python3.11/site-packages (from dandi) (0.4.7)
# Requirement already satisfied: acres in /home/emcclung/.local/lib/python3.11/site-packages (from bidsschematools~=1.0->dandi) (0.5.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from bidsschematools~=1.0->dandi) (6.0.1)
# Requirement already satisfied: jsonschema[format] in /opt/conda/lib/python3.11/site-packages (from dandischema~=0.12.0->dandi) (4.21.1)
# Requirement already satisfied: pydantic-settings in /home/emcclung/.local/lib/python3.11/site-packages (from dandischema~=0.12.0->dandi) (2.13.1)
# Requirement already satisfied: ci-info>=0.2 in /home/emcclung/.local/lib/python3.11/site-packages (from etelemetry>=0.2.2->dandi) (0.4.0)
# Requirement already satisfied: h5py>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from hdmf!=3.14.4,!=3.5.0->dandi) (3.11.0)
# Requirement already satisfied: numpy>=1.19.3 in /home/emcclung/.local/lib/python3.11/site-packages (from hdmf!=3.14.4,!=3.5.0->dandi) (1.26.4)
# Requirement already satisfied: pandas<3,>=1.2.0 in /home/emcclung/.local/lib/python3.11/site-packages (from hdmf!=3.14.4,!=3.5.0->dandi) (1.5.3)
# Requirement already satisfied: SecretStorage>=3.2 in /home/emcclung/.local/lib/python3.11/site-packages (from keyring!=23.9.0->dandi) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /home/emcclung/.local/lib/python3.11/site-packages (from keyring!=23.9.0->dandi) (0.9.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in /opt/conda/lib/python3.11/site-packages (from keyring!=23.9.0->dandi) (7.1.0)
# Requirement already satisfied: jaraco.classes in /home/emcclung/.local/lib/python3.11/site-packages (from keyring!=23.9.0->dandi) (3.4.0)
# Requirement already satisfied: jaraco.functools in /home/emcclung/.local/lib/python3.11/site-packages (from keyring!=23.9.0->dandi) (4.4.0)
# Requirement already satisfied: jaraco.context in /home/emcclung/.local/lib/python3.11/site-packages (from keyring!=23.9.0->dandi) (6.1.0)
# Requirement already satisfied: deprecated in /home/emcclung/.local/lib/python3.11/site-packages (from numcodecs<0.16->dandi) (1.3.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from nwbinspector!=0.4.32,>=0.4.28->dandi) (3.9.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from nwbinspector!=0.4.32,>=0.4.28->dandi) (2024.3.1)
# Requirement already satisfied: hdmf-zarr in /home/emcclung/.local/lib/python3.11/site-packages (from nwbinspector!=0.4.32,>=0.4.28->dandi) (0.12.0)
# Requirement already satisfied: isodate in /home/emcclung/.local/lib/python3.11/site-packages (from nwbinspector!=0.4.32,>=0.4.28->dandi) (0.7.2)
# Requirement already satisfied: natsort in /home/emcclung/.local/lib/python3.11/site-packages (from nwbinspector!=0.4.32,>=0.4.28->dandi) (8.4.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from nwbinspector!=0.4.32,>=0.4.28->dandi) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/emcclung/.local/lib/python3.11/site-packages (from pydantic~=2.0->dandi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/emcclung/.local/lib/python3.11/site-packages (from pydantic~=2.0->dandi) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/emcclung/.local/lib/python3.11/site-packages (from pydantic~=2.0->dandi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/emcclung/.local/lib/python3.11/site-packages (from pydantic~=2.0->dandi) (0.4.2)
# Requirement already satisfied: blessed in /home/emcclung/.local/lib/python3.11/site-packages (from pyout!=0.6.0,>=0.5->dandi) (1.32.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil->dandi) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests~=2.20->dandi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests~=2.20->dandi) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests~=2.20->dandi) (2024.8.30)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.11/site-packages (from ruamel.yaml<1,>=0.15->dandi) (0.2.8)
# Requirement already satisfied: multidict>=4.0 in /opt/conda/lib/python3.11/site-packages (from yarl~=1.9->dandi) (6.0.5)
# Requirement already satisfied: asciitree in /home/emcclung/.local/lib/python3.11/site-packages (from zarr<=3.1.5,>=2.10->dandi) (0.3.3)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/emcclung/.local/lib/python3.11/site-packages (from tensorstore->dandi) (0.5.4)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata>=4.11.4->keyring!=23.9.0->dandi) (3.17.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3,>=1.2.0->hdmf!=3.14.4,!=3.5.0->dandi) (2024.1)
# Requirement already satisfied: email-validator>=2.0.0 in /home/emcclung/.local/lib/python3.11/site-packages (from pydantic[email]~=2.4->dandischema~=0.12.0->dandi) (2.3.0)
# Requirement already satisfied: cryptography>=2.0 in /opt/conda/lib/python3.11/site-packages (from SecretStorage>=3.2->keyring!=23.9.0->dandi) (42.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->nwbinspector!=0.4.32,>=0.4.28->dandi) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->nwbinspector!=0.4.32,>=0.4.28->dandi) (1.4.1)
# Requirement already satisfied: wcwidth>=0.6 in /home/emcclung/.local/lib/python3.11/site-packages (from blessed->pyout!=0.6.0,>=0.5->dandi) (0.6.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/conda/lib/python3.11/site-packages (from deprecated->numcodecs<0.16->dandi) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from hdmf-zarr->nwbinspector!=0.4.32,>=0.4.28->dandi) (3.4.0)
# Requirement already satisfied: more-itertools in /home/emcclung/.local/lib/python3.11/site-packages (from jaraco.classes->keyring!=23.9.0->dandi) (10.8.0)
# Requirement already satisfied: backports.tarfile in /home/emcclung/.local/lib/python3.11/site-packages (from jaraco.context->keyring!=23.9.0->dandi) (1.2.0)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (2.4)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (0.1.4)
# Requirement already satisfied: rfc3987 in /home/emcclung/.local/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (1.3.8)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]->dandischema~=0.12.0->dandi) (1.13)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/emcclung/.local/lib/python3.11/site-packages (from pydantic-settings->dandischema~=0.12.0->dandi) (1.2.2)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring!=23.9.0->dandi) (1.16.0)
# Requirement already satisfied: dnspython>=2.0.0 in /home/emcclung/.local/lib/python3.11/site-packages (from email-validator>=2.0.0->pydantic[email]~=2.4->dandischema~=0.12.0->dandi) (2.8.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from isoduration->jsonschema[format]->dandischema~=0.12.0->dandi) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format]->dandischema~=0.12.0->dandi) (2.9.0.20240316)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring!=23.9.0->dandi) (2.22)
# PATH                                                      SIZE      DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-19T12-45-31.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-16T13-05-50.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-17T13-09-45.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-26T13-41-50.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-27T13-51-35.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-28T13-14-50.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-01T13-57-44.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-29T12-58-05.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-06-30T13-26-28.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-06T13-37-03.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-02T13-15-40.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-08T13-58-45.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-07T13-06-26.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-09T13-01-26.nwb 376.9 MB  376.9 MB         100%    ok    done
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-10T12-50-36.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-13T13-06-07.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-15T13-22-44.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-10T13-51-37.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-12T13-18-51.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-14T13-25-33.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-16T12-44-16.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-21T13-00-24.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-17T12-54-39.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-20T12-59-25.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-22T13-14-32.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-23T12-27-21.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-27T13-14-26.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-30T11-11-28.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-29T11-26-39.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-24T12-31-24.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-07-31T12-03-31.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-08-03T11-23-03.nwb                                          error           FileExistsError
# sub-028-392/sub-028-392_ses-FP-PR-2020-08-04T11-50-34.nwb                                          error           FileExistsError
# Summary:                                                  376.9 MB  376.9 MB                       32 error        32 FileExistsError
#                                                           +112.4 MB 77.03%                         1 done
#                                                                     ETA: a minute
# 2026-03-06 01:49:46,841 [   ERROR] Encountered 32 errors while downloading. The first error: {'status': 'error', 'message': 'FileExistsError', 'path': 'sub-028-392/sub-028-392_ses-FP-PR-2020-06-19T12-45-31.nwb'}
# 2026-03-06 01:49:46,847 [    INFO] Logs saved in /home/emcclung/.local/state/dandi-cli/log/2026.03.06-01.45.42Z-541.log
# Error: Encountered 32 errors while downloading.

# %%
#look through the files to open up a specific one
os.listdir("data")

#create list  of file names
data_dir = "data/sub-028-392"
files = os.listdir(data_dir)

#pick a NWB file
actual_filename = [f for f in files if f.endswith('.nwb')][0]
file_path = os.path.join(data_dir, actual_filename)

#open the file
with NWBHDF5IO(file_path, "r") as io:
    nwb = io.read()
    print(nwb)
# Out:
# Files found: ['sub-028-392_ses-FP-PR-2020-07-16T12-44-16.nwb', 'sub-028-392_ses-FP-PR-2020-07-30T11-11-28.nwb', 'sub-028-392_ses-FP-PR-2020-07-23T12-27-21.nwb', 'sub-028-392_ses-FP-PR-2020-07-13T13-06-07.nwb', 'sub-028-392_ses-FP-PR-2020-07-31T12-03-31.nwb', 'sub-028-392_ses-FP-PR-2020-06-30T13-26-28.nwb', 'sub-028-392_ses-FP-PR-2020-07-10T13-51-37.nwb', 'sub-028-392_ses-FP-PR-2020-08-03T11-23-03.nwb', 'sub-028-392_ses-FP-PR-2020-07-27T13-14-26.nwb', 'sub-028-392_ses-FP-PR-2020-07-02T13-15-40.nwb', 'sub-028-392_ses-FP-PR-2020-07-14T13-25-33.nwb', 'sub-028-392_ses-FP-PR-2020-06-19T12-45-31.nwb', 'sub-028-392_ses-FP-PR-2020-06-27T13-51-35.nwb', 'sub-028-392_ses-FP-PR-2020-06-26T13-41-50.nwb', 'sub-028-392_ses-FP-PR-2020-07-07T13-06-26.nwb', 'sub-028-392_ses-FP-PR-2020-07-15T13-22-44.nwb', 'sub-028-392_ses-FP-PR-2020-07-06T13-37-03.nwb', 'sub-028-392_ses-FP-PR-2020-07-01T13-57-44.nwb', 'sub-028-392_ses-FP-PR-2020-07-09T13-01-26.nwb', 'sub-028-392_ses-FP-PR-2020-07-20T12-59-25.nwb', 'sub-028-392_ses-FP-PR-2020-07-12T13-18-51.nwb', 'sub-028-392_ses-FP-PR-2020-07-08T13-58-45.nwb', 'sub-028-392_ses-FP-PR-2020-08-04T11-50-34.nwb', 'sub-028-392_ses-FP-PR-2020-07-29T11-26-39.nwb', 'sub-028-392_ses-FP-PR-2020-07-24T12-31-24.nwb', 'sub-028-392_ses-FP-PR-2020-06-16T13-05-50.nwb', 'sub-028-392_ses-FP-PR-2020-06-17T13-09-45.nwb', 'sub-028-392_ses-FP-PR-2020-06-28T13-14-50.nwb', 'sub-028-392_ses-FP-PR-2020-07-10T12-50-36.nwb', 'sub-028-392_ses-FP-PR-2020-06-29T12-58-05.nwb', 'sub-028-392_ses-FP-PR-2020-07-17T12-54-39.nwb', 'sub-028-392_ses-FP-PR-2020-07-22T13-14-32.nwb', 'sub-028-392_ses-FP-PR-2020-07-21T13-00-24.nwb']
#
# Opening: data/sub-028-392/sub-028-392_ses-FP-PR-2020-07-16T12-44-16.nwb
# root pynwb.file.NWBFile at 0x140449287135056
# Fields:
#   experiment_description: Compulsive behavior is a defining feature of disorders such as substance use disorders. Current evidence suggests that corticostriatal circuits control the expression of established compulsions, but little is known about the mechanisms regulating the development of compulsions. We hypothesized that dopamine, a critical modulator of striatal synaptic plasticity, could control alterations in corticostriatal circuits leading to the development of compulsions (defined here as continued reward seeking in the face of punishment). We used dual-site fiber photometry to measure dopamine axon activity in the dorsomedial striatum (DMS) and the dorsolateral striatum (DLS) as compulsions emerged. Individual variability in the speed with which compulsions emerged was predicted by DMS dopamine axon activity. Amplifying this dopamine signal accelerated animals' transitions to compulsion, whereas inhibition delayed it. In contrast, amplifying DLS dopamine signaling had no effect on the emergence of compulsions. These results establish DMS dopamine signaling as a key controller of the development of compulsive reward seeking.
#   experimenter: ['Seiler, Jillian L.' 'Cosme, Caitlin V.' 'Sherathiya, Venus N.'
#  'Schaid, Michael D.' 'Bianco, Joseph M.' 'Bridgemohan, Abigael S.'
#  'Lerner, Talia N.']
#   file_create_date: [datetime.datetime(2024, 6, 17, 18, 24, 8, 377918, tzinfo=tzoffset(None, -25200))]
#   identifier: d757d567-78b0-4978-a7d0-a896478d683e
#   institution: Northwestern Unitersity
#   keywords: <StrDataset for HDF5 dataset "keywords": shape (9,), type "|O">
#   lab: Lerner
#   notes: Hemisphere with DMS: Left
# Experiment: Fiber Photometry
# Behavior: RI60
# Punishment Group: Punishment Resistant
# Did Not Learn: False
#
#   processing: {
#     behavior <class 'pynwb.base.ProcessingModule'>
#   }
#   related_publications: ['https://doi.org/10.1016/j.cub.2022.01.055']
#   session_description: RI60 Training with concurrent fiber photometry, rewards delivered on right nose pokes
#   session_id: FP_PR_2020-07-16T12-44-16
#   session_start_time: 2020-07-16 12:44:16-05:51
#   source_script: Created using NeuroConv v0.4.11
#   source_script_file_name: /opt/anaconda3/envs/lerner_lab_to_nwb_env/lib/python3.12/site-packages/neuroconv/basedatainterface.py
#   subject: subject pynwb.file.Subject at 0x140447853828624
# Fields:
#   age: P10W/
#   age__reference: birth
#   description: Male and female WT (C57BL/6J) and (DAT)::IRES-Cre knockin mice (JAX006660) were obtained from The Jackson Laboratory and crossed in house. Only heterozygote transgenic mice, obtained by backcrossing to C57BL/6J wildtypes, were used for experiments. Littermates of the same sex were randomly assigned to experimental groups (fiber photometry-14 males, 22 females; DMS excitatory optogenetics- 20 males, 19 females; DMS inhibitory optogenetics- 13 males, 13 females; DLS excitatory optogenetics- 18 males, 18 females). Adult mice at least 10 weeks of age were used in all experiments. Mice were group housed under a conventional 12 h light cycle (dark from 7:00pm to 7:00am) with ad libitum access to food and water prior to operant training. All experiments were approved by the Northwestern University Institutional Animal Care and Use Committee.
#   genotype: DAT-IRES-Cre: B6.SJLSlc6a3tm1.1(cre)Bkmn/J
#   sex: M
#   species: Mus musculus
#   strain: C57BL/6J
#   subject_id: 028.392
#
#   surgery: GCaMP7b in DMS & DLS projecting SNc, fiber photometry probes in DMS & DLS
#   timestamps_reference_time: 2020-07-16 12:44:16-05:51
#   virus: AAV5-CAG-FLEX-jGCaMP7b-WPRE
# /home/emcclung/.local/lib/python3.11/site-packages/hdmf/spec/namespace.py:484: UserWarning: Schema conflict(s) detected in namespace 'ndx-fiber-photometry':
#  ndx-fiber-photometry defines OpticalFiber.model as an attribute (dtype: text) while the core schema defines it as a link to DeviceModel.
# ndx-fiber-photometry defines ExcitationSource.model as an attribute (dtype: text) while the core schema defines it as a link to DeviceModel.
# ndx-fiber-photometry defines Photodetector.model as an attribute (dtype: text) while the core schema defines it as a link to DeviceModel.
# ndx-fiber-photometry defines DichroicMirror.model as an attribute (dtype: text) while the core schema defines it as a link to DeviceModel.
# ndx-fiber-photometry defines BandOpticalFilter.model as an attribute (dtype: text) while the core schema defines it as a link to DeviceModel.
# ndx-fiber-photometry defines EdgeOpticalFilter.model as an attribute (dtype: text) while the core schema defines it as a link to DeviceModel.
# This may cause compatibility issues. Please update the extension version if possible or install an older version of the core schema that is compatible.
#   self._check_namespace_conflicts(extension_ns_name=ns_name,

# %%
#path to one subjects data
file_path = "data/sub-028-392/sub-028-392_ses-FP-PR-2020-07-09T13-01-26.nwb"

with NWBHDF5IO(file_path, "r") as io:
    nwb = io.read()
    
    #get the photometry signal
    fp_series = nwb.acquisition['fiber_photometry_response_series']
    raw_signal = fp_series.data[:]
    rate = fp_series.rate
    start = fp_series.starting_time
    timestamps = start + (np.arange(len(raw_signal)) / rate)
    
    signal = raw_signal[:, 0]

    #get the behavioral events
    beh = nwb.processing['behavior'].data_interfaces
    
    #get timestamps for each event type
    reward_times = beh['right_reward_times'].timestamps[:]
    left_pokes = beh['left_nose_poke_times'].timestamps[:]
    right_pokes = beh['right_nose_poke_times'].timestamps[:]
 
    #combine nose pokes into into one event
    all_pokes = np.sort(np.concatenate([left_pokes, right_pokes]))

#format and save
data_dict = {
    "signal": signal.astype(np.float32),
    "timestamps": timestamps.astype(np.float32),
    "events": {
        "reward": reward_times.astype(np.float32),
        "nose_poke": all_pokes.astype(np.float32)
    },
    "metadata": {
        "sampling_rate": rate,
        "session_id": "sub-028-392_2020-07-09"
    }
}

np.save("data_for_dunl.npy", data_dict)

print("finish preprocess")
# Out:
# --- Extraction Complete ---
# Photometry samples: 3926016
# Rewards found:      32
# Total Nose Pokes:   90
#
# You are now ready to run the DUNL preprocess_scripts!

# %%
# 1. LOAD the data we extracted earlier
# (Make sure this matches the filename from our previous step)
data_path = "dunl-compneuro/data/data_for_dunl.npy"
data = np.load(data_path, allow_pickle=True).item()

# 2. CONFIGURATION (The "Step 2" part)
bin_size = 0.02  # 20ms bins (standard for dopamine analysis)
kernel_length_sec = 5.0  # We want to model 5 seconds of dopamine response
bins_per_kernel = int(kernel_length_sec / bin_size)

# 3. PREPROCESSING (Turning timestamps into a timeline)
max_time = data['timestamps'][-1]
time_bins = np.arange(0, max_time, bin_size)

# Bin the photometry signal
# We take the average signal value in each 20ms window
binned_signal, _ = np.histogram(data['timestamps'], bins=time_bins, weights=data['signal'])
counts, _ = np.histogram(data['timestamps'], bins=time_bins)
# Avoid division by zero
final_signal = np.divide(binned_signal, counts, out=np.zeros_like(binned_signal), where=counts!=0)

# Z-Score the signal (Normalization)
final_signal = (final_signal - np.mean(final_signal)) / np.std(final_signal)

# Bin the events (1 if it happened, 0 if not)
reward_vec, _ = np.histogram(data['events']['reward'], bins=time_bins)
poke_vec, _ = np.histogram(data['events']['nose_poke'], bins=time_bins)

# 4. SAVE for the DUNL Model
# We package it as a PyTorch file (.pt) which the DUNL code prefers
dunl_input = {
    "signal": torch.tensor(final_signal).float(),
    "reward": torch.tensor(reward_vec).float().clamp(0, 1), # Ensure it's binary 0 or 1
    "nose_poke": torch.tensor(poke_vec).float().clamp(0, 1)
}

# Create a folder for the result
os.makedirs("dunl_ready_data", exist_ok=True)
torch.save(dunl_input, "dunl_ready_data/session_01.pt")

print("--- Preprocessing Complete ---")
print(f"Total bins: {len(final_signal)}")
print(f"File saved to: dunl_ready_data/session_01.pt")
# Out:
# --- Preprocessing Complete ---
# Total bins: 192971
# File saved to: dunl_ready_data/session_01.pt

# %% [markdown]
# ## 4. Conclusion & Discussion (~400-500 words)
#
# Discussion of your results and how they address your scientific question.
# Limitations of analysis discussed.
# What additional experiments would be interesting, and what data would you need?

# %% [markdown]
# ## 5. Reflection  (~100-200 words)
#
# In 100-200 words, please reflect on this project as a whole, from the proposal to the final product. How did you integrate and address feedback on the proposal? What was difficult? What was rewarding? Did this go as planned?

# %% [markdown]
# ## 6. List of Contributions & AI Usage Statement

# %% [markdown]
# 7. Code Clarity, Readability & Style
